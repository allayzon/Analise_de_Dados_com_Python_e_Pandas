# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
# upload do arquivo
from google.colab import files 
arq = files.upload()
# Out:
#      <input type="file" id="files-413de3b0-cafc-48d7-a562-ec79e17e3ac7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-413de3b0-cafc-48d7-a562-ec79e17e3ac7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving AdventureWorks.xlsx to AdventureWorks.xlsx

# %%
df = pd.read_excel('AdventureWorks.xlsx')

# %%
df.head()
# Out:
#   Data Venda Data Envio  ID Loja  ...            Marca   Classe  Cor
# 0 2008-05-09 2008-05-29      199  ...  Adventure Works  Regular  Red
# 1 2008-05-12 2008-05-17      306  ...  Adventure Works  Regular  Red
# 2 2008-05-14 2008-05-20      306  ...  Adventure Works  Regular  Red
# 3 2008-05-21 2008-05-27      306  ...  Adventure Works  Regular  Red
# 4 2008-06-20 2008-06-27      306  ...  Adventure Works  Regular  Red
#
# [5 rows x 16 columns]

# %%
df.shape
# Out:
# (904, 16)

# %%
df.dtypes
# Out:
# Data Venda        datetime64[ns]
# Data Envio        datetime64[ns]
# ID Loja                    int64
# ID Produto                 int64
# ID Cliente                 int64
# No. Venda                 object
# Custo Unitário           float64
# Preço Unitário           float64
# Quantidade                 int64
# Valor Desconto           float64
# Valor Venda              float64
# Produto                   object
# Fabricante                object
# Marca                     object
# Classe                    object
# Cor                       object
# dtype: object

# %%
df['Valor Venda'].sum()
# Out:
# 5984606.1426

# %%
# Qual o custo total?
df['custo'] = df['Custo Unitário'].mul(df['Quantidade']) # Criando a coluna de custo
df.head()
# Out:
#   Data Venda Data Envio  ID Loja  ...   Classe  Cor    custo
# 0 2008-05-09 2008-05-29      199  ...  Regular  Red  2091.48
# 1 2008-05-12 2008-05-17      306  ...  Regular  Red  2091.48
# 2 2008-05-14 2008-05-20      306  ...  Regular  Red  2091.48
# 3 2008-05-21 2008-05-27      306  ...  Regular  Red  2091.48
# 4 2008-06-20 2008-06-27      306  ...  Regular  Red  2091.48
#
# [5 rows x 17 columns]

# %%
# Qual o custo Total?
round(df['custo'].sum(), 2)
# Out:
# 2486783.05

# %%
df['lucro'] = df['Valor Venda'] - df['custo']
df.head()
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ...   Classe  Cor    custo    lucro
# 0 2008-05-09 2008-05-29      199         384  ...  Regular  Red  2091.48  2456.52
# 1 2008-05-12 2008-05-17      306         384  ...  Regular  Red  2091.48  2456.52
# 2 2008-05-14 2008-05-20      306         384  ...  Regular  Red  2091.48  2456.52
# 3 2008-05-21 2008-05-27      306         384  ...  Regular  Red  2091.48  2456.52
# 4 2008-06-20 2008-06-27      306         384  ...  Regular  Red  2091.48  2456.52
#
# [5 rows x 18 columns]

# %%
# Criando uma coluna com total de dias para enviar o produto
df['Tempo_envio'] = df['Data Envio'] - df['Data Venda']
df.head()
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ...  Cor    custo    lucro  Tempo_envio
# 0 2008-05-09 2008-05-29      199         384  ...  Red  2091.48  2456.52      20 days
# 1 2008-05-12 2008-05-17      306         384  ...  Red  2091.48  2456.52       5 days
# 2 2008-05-14 2008-05-20      306         384  ...  Red  2091.48  2456.52       6 days
# 3 2008-05-21 2008-05-27      306         384  ...  Red  2091.48  2456.52       6 days
# 4 2008-06-20 2008-06-27      306         384  ...  Red  2091.48  2456.52       7 days
#
# [5 rows x 19 columns]

# %%
# Note que a coluna tempo_envio está em string (x days), precisamos passar pra date
df['Tempo_envio'] = (df['Data Envio'] - df['Data Venda']).dt.days  # Está como int agr, se quisermos, podemos passar pra date type ou permanecer desse jeito
df.head()
# Out:
#   Data Venda Data Envio  ID Loja  ...    custo    lucro Tempo_envio
# 0 2008-05-09 2008-05-29      199  ...  2091.48  2456.52          20
# 1 2008-05-12 2008-05-17      306  ...  2091.48  2456.52           5
# 2 2008-05-14 2008-05-20      306  ...  2091.48  2456.52           6
# 3 2008-05-21 2008-05-27      306  ...  2091.48  2456.52           6
# 4 2008-06-20 2008-06-27      306  ...  2091.48  2456.52           7
#
# [5 rows x 19 columns]

# %%
df.groupby('Marca')['Tempo_envio'].mean()
# Out:
# Marca
# Adventure Works    8.663866
# Contoso            8.470930
# Fabrikam           8.510121
# Name: Tempo_envio, dtype: float64

# %% [markdown]
# ## Missing Values

# %%
df.isnull().sum()
# Out:
# Data Venda        0
# Data Envio        0
# ID Loja           0
# ID Produto        0
# ID Cliente        0
# No. Venda         0
# Custo Unitário    0
# Preço Unitário    0
# Quantidade        0
# Valor Desconto    0
# Valor Venda       0
# Produto           0
# Fabricante        0
# Marca             0
# Classe            0
# Cor               0
# custo             0
# lucro             0
# Tempo_envio       0
# dtype: int64

# %% [markdown]
# ## Lucro por ano e por marca

# %%
pd.options.display.float_format = '{:20,.2f}'.format  # Formatando a exibição do lucro a baixo

# %%
df.groupby([df['Data Venda'].dt.year, 'Marca'])['lucro'].sum()
# Out:
# Data Venda  Marca
# 2008        Adventure Works             306,641.16
#             Contoso                      56,416.00
#             Fabrikam                  1,557,020.55
# 2009        Adventure Works             405,395.08
#             Contoso                     138,258.95
#             Fabrikam                  1,034,091.35
# Name: lucro, dtype: float64

# %%
# Resetando o index
lucro_ano = df.groupby([df['Data Venda'].dt.year, 'Marca'])['lucro'].sum().reset_index()
lucro_ano
# Out:
#    Data Venda            Marca                lucro
# 0        2008  Adventure Works           306,641.16
# 1        2008          Contoso            56,416.00
# 2        2008         Fabrikam         1,557,020.55
# 3        2009  Adventure Works           405,395.08
# 4        2009          Contoso           138,258.95
# 5        2009         Fabrikam         1,034,091.35

# %%
df.groupby('Produto')['Quantidade'].sum().sort_values(ascending=False)
# Out:
# Produto
# Headphone Adapter for Contoso Phone E130 Silver    25232
# Headphone Adapter for Contoso Phone E130 White     25008
# Adventure Works Laptop15.4W M1548 Black             1089
# Fabrikam Trendsetter 2/3'' 17mm X100 Grey           1087
# Adventure Works Laptop15.4W M1548 Red               1047
# Fabrikam Trendsetter 2/3'' 17mm X100 Black           926
# Fabrikam Trendsetter 1/3'' 8.5mm X200 Black          884
# Fabrikam Trendsetter 1/3'' 8.5mm X200 Grey           845
# Fabrikam Trendsetter 1/3'' 8.5mm X200 White          789
# Name: Quantidade, dtype: int64

# %%
# Gráfico Total de Produtos Vendidos 
df.groupby('Produto')['Quantidade'].sum().sort_values(ascending=True).plot.barh(title='Total Produtos Vendidos')
plt.xlabel('Total')
plt.xlabel('Produto');

# %%
df.groupby(df['Data Venda'].dt.year)['lucro'].sum().plot.bar(title=' Lucro x Ano')
plt.xlabel('Ano')
plt.ylabel('Receita');

# %%
df.groupby(df['Data Venda'].dt.year)['lucro'].sum()
# Out:
# Data Venda
# 2008           1,920,077.71
# 2009           1,577,745.38
# Name: lucro, dtype: float64

# %%
# Selecionando apenas as vendas de 2009 
df_2009 = df[df['Data Venda'].dt.year == 2009]

# %%
df_2009.head()
# Out:
#    Data Venda Data Envio  ...                lucro  Tempo_envio
# 11 2009-05-02 2009-05-14  ...             2,456.52           12
# 12 2009-05-16 2009-05-27  ...             2,456.52           11
# 13 2009-05-31 2009-06-12  ...             2,456.52           12
# 14 2009-06-28 2009-07-11  ...             2,456.52           13
# 15 2009-07-08 2009-07-12  ...             2,456.52            4
#
# [5 rows x 19 columns]

# %%
df_2009.groupby(df_2009['Data Venda'].dt.month)['lucro'].sum().plot(title='Lucro x Mês')
plt.xlabel('Mês')
plt.ylabel('Lucro');

# %%
df_2009.groupby('Marca')['lucro'].sum().plot.bar(title='Lucro x Marca')
plt.xlabel('Marca')
plt.ylabel('Lucro')
plt.xticks(rotation='horizontal');  # Passamos a legenda na horizontal

# %%
df_2009.groupby('Classe')['lucro'].sum().plot.bar(title='Lucro x Classe')
plt.xlabel('Classe')
plt.ylabel('Lucro')
plt.xticks(rotation='horizontal');

# %%
df['Tempo_envio'].describe()
# Out:
# count                 904.00
# mean                    8.54
# std                     3.06
# min                     4.00
# 25%                     6.00
# 50%                     9.00
# 75%                    11.00
# max                    20.00
# Name: Tempo_envio, dtype: float64

# %%
# Gráfico de Boxplot
plt.boxplot(df['Tempo_envio'])  # Esse ponto solto no gráfico é um outlier que é um valor discrepante, o resto são os dados listados acima (min, media, mediana, max)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7ff899b7a2d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7ff899b90e50>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7ff899b8fe90>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7ff899b90150>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7ff899b7a350>,
#   <matplotlib.lines.Line2D at 0x7ff899c36a50>]}

# %%
# Histograma
plt.hist(df['Tempo_envio'])
# Out:
# (array([217., 137.,  70., 179., 115., 185.,   0.,   0.,   0.,   1.]),
#  array([ 4. ,  5.6,  7.2,  8.8, 10.4, 12. , 13.6, 15.2, 16.8, 18.4, 20. ]),
#  <a list of 10 Patch objects>)

# %%
# Tempo mínimo de envio
df['Tempo_envio'].min()
# Out:
# 4

# %%
# Tempo máximo de envio
df['Tempo_envio'].max()
# Out:
# 20

# %%
df[df['Tempo_envio'] == 20]
# Out:
#   Data Venda Data Envio  ...                lucro  Tempo_envio
# 0 2008-05-09 2008-05-29  ...             2,456.52           20
#
# [1 rows x 19 columns]

# %%
df.to_csv('df_vendas_novo.csv', index=False)
