# %%
frase = 'Slk, python é tudo de bom'
print(frase[0:10])
# Out:
# Slk, pytho

# %%
frase.count('python')
# Out:
# 1

# %%
frase.upper()
# Out:
# 'SLK, PYTHON É TUDO DE BOM'

# %%
frase.replace('python', 'py')
# Out:
# 'Slk, py é tudo de bom'
